# %% [markdown]
# # DATA LOADING

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Dataset/train.csv')

# %%
df.head()
# Out:
#                             customer_id firstname lastname  record_number  \
# 0  4814dfa2-45a8-46b9-8102-98ecbbec2d2a     Navya     Vasa              7
# 1  bb0abe41-cc89-4a1d-bb1c-48bd212ae00d      Azad  Warrior              5
# 2  edfd1a62-05da-4cfd-b8ae-521f05f0fd5f      Piya      Jha              1
# 3  3eaa4c2a-2316-48f4-b1b0-4aafe2286630      Rhea    Varma             11
# 4  c9a73239-baae-40eb-8855-dab07767ea86     Sahil     Dave             12
#
#    days_since_opened  days_since_confirmed  primary_term  final_term  \
# 0                 10                     8            12          10
# 1                 15                     6             7           6
# 2                 15                    17             8           5
# 3                  7                     2            11          13
# 4                 14                     9             8          11
#
#    days_till_primary_close  days_till_final_close  ...  encoded_payment_21  \
# ...

# %%
df.tail()
# Out:
#                                   customer_id firstname  lastname  \
# 1106669  c341a4e3-b4e2-455b-80b2-2be2655e6e85     Gatik     Boase
# 1106670  29d8337c-13c9-4bb6-b794-762c386b1866    Jhanvi     Andra
# 1106671  e3b374f2-d96e-4c8b-901a-be80a8bea3cc   Lakshit  Kulkarni
# 1106672  b81e5b47-5c1b-4302-897c-2edc179d583f  Parinaaz   Chaudry
# 1106673  62419cd3-7d86-4484-a684-93ace05cbbc0    Faiyaz      Mani
#
#          record_number  days_since_opened  days_since_confirmed  primary_term  \
# 1106669             19                  1                     5             8
# 1106670             10                  5                     8             4
# 1106671              3                  8                     7            13
# 1106672              4                 10                     4            16
# 1106673             12                  1                    10            10
#
#          final_term  days_till_primary_close  days_till_final_close  ...  \
# ...

# %%
df.shape
# Out:
# (1106674, 62)

# %% [markdown]
# # DATA EXPLORATION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106674 entries, 0 to 1106673
# Data columns (total 62 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   customer_id                         1106674 non-null  object
#  1   firstname                           1106674 non-null  object
#  2   lastname                            1106674 non-null  object
#  3   record_number                       1106674 non-null  int64
#  4   days_since_opened                   1106674 non-null  int64
#  5   days_since_confirmed                1106674 non-null  int64
#  6   primary_term                        1106674 non-null  int64
#  7   final_term                          1106674 non-null  int64
#  8   days_till_primary_close             1106674 non-null  int64
#  9   days_till_final_close               1106674 non-null  int64
#  10  loans_credit_limit                  1106674 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'firstname', 'lastname', 'record_number',
#        'days_since_opened', 'days_since_confirmed', 'primary_term',
#        'final_term', 'days_till_primary_close', 'days_till_final_close',
#        'loans_credit_limit', 'loans_next_payment_summary',
#        'loans_outstanding_balance', 'loans_max_overdue_amount',
#        'loans_credit_cost_rate', 'loans_within_5_days',
#        'loans_within_5_to_30_days', 'loans_within_30_to_60_days',
#        'loans_within_60_to_90_days', 'loans_over_90_days',
#        'is_zero_loans_within_5_days', 'is_zero_loans_within_5_to_30_days',
#        'is_zero_loans_within_30_to_60_days',
#        'is_zero_loans_within_60_to_90_days', 'is_zero_loans_over_90_days',
#        'utilization', 'over_limit_count', 'max_over_limit_count',
#        'is_zero_utilization', 'is_zero_over_limit_count',
#        'is_zero_max_over_limit_count', 'encoded_payment_0',
#        'encoded_payment_1', 'encoded_payment_2', 'encoded_payment_3',
# ...

# %%
# Columns containing null values
col_null_value = [col for col in df.columns if df[col].isnull().sum() !=0]
col_null_value
# Out:
# ['encoded_payment_0',
#  'encoded_payment_1',
#  'encoded_payment_2',
#  'encoded_payment_3',
#  'encoded_payment_4',
#  'encoded_payment_5',
#  'encoded_payment_6',
#  'encoded_payment_7',
#  'encoded_payment_8',
#  'encoded_payment_9',
#  'encoded_payment_10',
#  'encoded_payment_11',
#  'encoded_payment_12',
#  'encoded_payment_13',
#  'encoded_payment_14',
#  'encoded_payment_15',
#  'encoded_payment_16',
#  'encoded_payment_17',
#  'encoded_payment_18',
#  'encoded_payment_19',
#  'encoded_payment_20',
#  'encoded_payment_21',
#  'encoded_payment_22',
#  'encoded_payment_23',
#  'encoded_payment_24']

# %%
# Object type columns
obj_cols = [col for col in df.columns if df[col].dtype == object]
obj_cols
# Out:
# ['customer_id',
#  'firstname',
#  'lastname',
#  'is_zero_loans_within_5_days',
#  'is_zero_loans_within_5_to_30_days',
#  'is_zero_loans_within_30_to_60_days',
#  'is_zero_loans_within_60_to_90_days',
#  'is_zero_loans_over_90_days',
#  'is_zero_utilization',
#  'is_zero_over_limit_count',
#  'is_zero_max_over_limit_count']

# %%
# Numeric Columns
num_cols = [col for col in df.columns if df[col].dtype != object]
num_cols
# Out:
# ['record_number',
#  'days_since_opened',
#  'days_since_confirmed',
#  'primary_term',
#  'final_term',
#  'days_till_primary_close',
#  'days_till_final_close',
#  'loans_credit_limit',
#  'loans_next_payment_summary',
#  'loans_outstanding_balance',
#  'loans_max_overdue_amount',
#  'loans_credit_cost_rate',
#  'loans_within_5_days',
#  'loans_within_5_to_30_days',
#  'loans_within_30_to_60_days',
#  'loans_within_60_to_90_days',
#  'loans_over_90_days',
#  'utilization',
#  'over_limit_count',
#  'max_over_limit_count',
#  'encoded_payment_0',
#  'encoded_payment_1',
#  'encoded_payment_2',
#  'encoded_payment_3',
#  'encoded_payment_4',
#  'encoded_payment_5',
#  'encoded_payment_6',
#  'encoded_payment_7',
#  'encoded_payment_8',
#  'encoded_payment_9',
#  'encoded_payment_10',
#  'encoded_payment_11',
#  'encoded_payment_12',
#  'encoded_payment_13',
#  'encoded_payment_14',
#  'encoded_payment_15',
#  'encoded_payment_16',
#  'encoded_payment_17',
#  'encoded_payment_18',
# ...

# %%
# Outlier Detection
Outlier_Suspects = ['days_since_opened','days_since_confirmed','primary_term','final_term','days_till_primary_close','days_till_final_close','max_over_limit_count','over_limit_count','utilization']

for col in Outlier_Suspects:
        print(f'skew index value of {col} column: {df[col].skew()}')
# Out:
# skew index value of days_since_opened column: -0.028560677914836168
# skew index value of days_since_confirmed column: 0.11822816327169089
# skew index value of primary_term column: 0.07019140733441273
# skew index value of final_term column: -0.1267194628473496
# skew index value of days_till_primary_close column: 0.18300167359147024
# skew index value of days_till_final_close column: -0.3852210889728233
# skew index value of max_over_limit_count column: -2.730004934093213
# skew index value of over_limit_count column: 5.93052751740853
# skew index value of utilization column: -1.9827841608953494

# %% [markdown]
# 1. NORMAL DISTRIBUTION: Skew Index is close to zero
# 2. SKEWED DISTRIBUTION: Skew Index is not close to zero

# %%
Normally_Distributed = ['days_since_opened','days_since_confirmed','primary_term','final_term','days_till_primary_close']
for i in Normally_Distributed:
    sns.set_style('dark')
    sns.kdeplot(df[i])
    sns.despine()
    plt.show()

# %%
Skewly_Distributed = ['days_till_final_close','max_over_limit_count','over_limit_count','utilization']

for col in Skewly_Distributed:
    sns.set_style('dark')
    sns.kdeplot(df[col])
    sns.despine()
    plt.show()

# %%
# Short Statistical Analysis 
df.describe()
# Out:
#        record_number  days_since_opened  days_since_confirmed  primary_term  \
# count   1.106674e+06       1.106674e+06          1.106674e+06  1.106674e+06
# mean    9.149727e+00       9.433967e+00          8.231377e+00  8.408147e+00
# std     5.746106e+00       5.747728e+00          4.776280e+00  5.282007e+00
# min     1.000000e+00       0.000000e+00          0.000000e+00  0.000000e+00
# 25%     5.000000e+00       5.000000e+00          4.000000e+00  4.000000e+00
# 50%     9.000000e+00       1.000000e+01          9.000000e+00  8.000000e+00
# 75%     1.300000e+01       1.400000e+01          1.200000e+01  1.400000e+01
# max     4.700000e+01       1.900000e+01          1.700000e+01  1.700000e+01
#
#          final_term  days_till_primary_close  days_till_final_close  \
# count  1.106674e+06             1.106674e+06           1.106674e+06
# mean   8.282763e+00             7.273099e+00           8.193988e+00
# std    4.565543e+00             5.094787e+00           4.321941e+00
# ...

# %%
df = df.drop(columns = ['record_number'])

# %%
df.corr()
# Out:
# C:\Users\sibap\AppData\Local\Temp\ipykernel_25996\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                    days_since_opened  days_since_confirmed  \
# days_since_opened                           1.000000             -0.002696
# days_since_confirmed                       -0.002696              1.000000
# primary_term                                0.001033              0.010692
# final_term                                 -0.000939              0.016300
# days_till_primary_close                    -0.063718              0.055268
# days_till_final_close                      -0.002999             -0.134194
# loans_credit_limit                          0.003660              0.001498
# loans_next_payment_summary                  0.005322             -0.011964
# ...

# %%
df.cov()
# Out:
# C:\Users\sibap\AppData\Local\Temp\ipykernel_25996\1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                                    days_since_opened  days_since_confirmed  \
# days_since_opened                          33.036379             -0.074016
# days_since_confirmed                       -0.074016             22.812850
# primary_term                                0.031347              0.269749
# final_term                                 -0.024648              0.355435
# days_till_primary_close                    -1.865893              1.344909
# days_till_final_close                      -0.074505             -2.770148
# loans_credit_limit                          0.122971              0.041831
# loans_next_payment_summary                  0.038161             -0.071280
# ...

# %%
sns.violinplot(x='final_close_flag', y='loans_within_5_days',data=df)
# Out:
# <Axes: xlabel='final_close_flag', ylabel='loans_within_5_days'>

# %%
sns.violinplot(x='final_close_flag', y='loans_within_5_to_30_days',data=df)
# Out:
# <Axes: xlabel='final_close_flag', ylabel='loans_within_5_to_30_days'>

# %%
sns.violinplot(x='final_close_flag', y='loans_within_30_to_60_days',data=df)
# Out:
# <Axes: xlabel='final_close_flag', ylabel='loans_within_30_to_60_days'>

# %%
sns.violinplot(x='final_close_flag', y='loans_within_60_to_90_days',data=df)
# Out:
# <Axes: xlabel='final_close_flag', ylabel='loans_within_60_to_90_days'>

# %%
sns.violinplot(x='final_close_flag', y='loans_over_90_days',data=df)
# Out:
# <Axes: xlabel='final_close_flag', ylabel='loans_over_90_days'>

# %% [markdown]
# ---->From above violin plots, Borrower with number of loans overdue greater than 8 over 90 days or more possess potential risk of credit default

# %%
sns.countplot(x=df['final_close_flag'])
# Out:
# <Axes: xlabel='final_close_flag', ylabel='count'>

# %% [markdown]
# ----> Above countplot shows there is class imbalance in final_close_flag column

# %% [markdown]
# # Summary Of Data Exploration
# 1. There are 62 columns in dataset (Numerical Features = 51, Textual Features = 11).
# 2. There are 23 columns containing null values.
# 3. There are 9 columns with outliers
# 4. It was found from analysis using violin plot that if an borrower has more than 8 overdue loans then, there is high risk of credit default
# 5. Class Imbalance is found in final close flag column aka target column

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# PLAN OF ACTION:
# 1. REMOVAL OF NULL VALUES
# 2. FEATURE ENCODING
# 3. OUTLIER REMOVAL
# 4. FIXING CLASS IMBALANCE
# 5. DROPPING IRRELEVANT COLUMNS

# %%
# 1. Removing null values
for col in col_null_value:

    # Calculating mode
    mode = df[col].mode()[0]

    # Imputing null values with mode
    df[col] = df[col].fillna(mode)

# %%
# 2. Feature Encoding
from sklearn.preprocessing import LabelEncoder 

encoder = LabelEncoder()

for col in obj_cols:
    df[col] = encoder.fit_transform(df[col])

# %%
# 3.  Outlier Removal 

columns = df.columns.to_list()

for col in columns:
    
    if col in Normally_Distributed:
        mean = df[col].mean()
        std = df[col].std()
        upper_limit = mean + 3*std 
        lower_limit = mean - 3*std 
        df[col] = np.where(df[col]>upper_limit,upper_limit,np.where(df[col]<lower_limit,lower_limit,df[col]))
    
    elif col in Skewly_Distributed:
        percentile_25 = df[col].quantile(0.25)
        percentile_75 = df[col].quantile(0.75)
        IQR = percentile_75 - percentile_25
        upper_limit = percentile_75 + 1.5*IQR 
        lower_limit = percentile_25 + 1.5*IQR 
        df[col] = np.where(df[col]>upper_limit,upper_limit,np.where(df[col]<lower_limit,lower_limit,df[col]))

# %%
df.columns
# Out:
# Index(['customer_id', 'firstname', 'lastname', 'days_since_opened',
#        'days_since_confirmed', 'primary_term', 'final_term',
#        'days_till_primary_close', 'days_till_final_close',
#        'loans_credit_limit', 'loans_next_payment_summary',
#        'loans_outstanding_balance', 'loans_max_overdue_amount',
#        'loans_credit_cost_rate', 'loans_within_5_days',
#        'loans_within_5_to_30_days', 'loans_within_30_to_60_days',
#        'loans_within_60_to_90_days', 'loans_over_90_days',
#        'is_zero_loans_within_5_days', 'is_zero_loans_within_5_to_30_days',
#        'is_zero_loans_within_30_to_60_days',
#        'is_zero_loans_within_60_to_90_days', 'is_zero_loans_over_90_days',
#        'utilization', 'over_limit_count', 'max_over_limit_count',
#        'is_zero_utilization', 'is_zero_over_limit_count',
#        'is_zero_max_over_limit_count', 'encoded_payment_0',
#        'encoded_payment_1', 'encoded_payment_2', 'encoded_payment_3',
# ...

# %%
# 4. Dropping Irrelevant Column
df = df.drop(columns = ['customer_id','firstname','lastname'])

# %%
df.head()
# Out:
#    days_since_opened  days_since_confirmed  primary_term  final_term  \
# 0               10.0                   8.0          12.0        10.0
# 1               15.0                   6.0           7.0         6.0
# 2               15.0                  17.0           8.0         5.0
# 3                7.0                   2.0          11.0        13.0
# 4               14.0                   9.0           8.0        11.0
#
#    days_till_primary_close  days_till_final_close  loans_credit_limit  \
# 0                     13.0                   14.0                  11
# 1                      9.0                   14.0                   5
# 2                      9.0                   14.0                   6
# 3                     14.0                   14.0                  14
# 4                      6.0                   14.0                   5
#
#    loans_next_payment_summary  loans_outstanding_balance  \
# 0                           2                          3
# ...

# %%
df['final_close_flag'].value_counts()
# Out:
# 0    895249
# 1    211425
# Name: final_close_flag, dtype: int64

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
y = df['final_close_flag']
x = df.drop(columns=['final_close_flag'])

# %%
# 5. Solving issue of class imbalance
import imblearn
from imblearn.over_sampling import SMOTE

sampler = SMOTE(random_state=36)

x_resample, y_resample = sampler.fit_resample(x,y)

# %%
y_resample.value_counts()
# Out:
# 0    895249
# 1    895249
# Name: final_close_flag, dtype: int64

# %%
df1 = pd.concat([x_resample,y_resample],axis=1)

# %%
df1.head()
# Out:
#    days_since_opened  days_since_confirmed  primary_term  final_term  \
# 0               10.0                   8.0          12.0        10.0
# 1               15.0                   6.0           7.0         6.0
# 2               15.0                  17.0           8.0         5.0
# 3                7.0                   2.0          11.0        13.0
# 4               14.0                   9.0           8.0        11.0
#
#    days_till_primary_close  days_till_final_close  loans_credit_limit  \
# 0                     13.0                   14.0                  11
# 1                      9.0                   14.0                   5
# 2                      9.0                   14.0                   6
# 3                     14.0                   14.0                  14
# 4                      6.0                   14.0                   5
#
#    loans_next_payment_summary  loans_outstanding_balance  \
# 0                           2                          3
# ...

# %%
df1.shape
# Out:
# (1790498, 58)

# %% [markdown]
# # FEATURE SELECTION

# %%
# 1. Feature Set Using Mutual Information Score
from sklearn.feature_selection import mutual_info_classif 
from sklearn.feature_selection import SelectKBest 

y_final_close = df1.final_close_flag
y_primary_close = df1.primary_close_flag 
x = df1.drop(columns = ['final_close_flag','primary_close_flag'])

selector = SelectKBest(mutual_info_classif, k=45)

x_new = selector.fit_transform(x,y_final_close)

# %%
selector.get_feature_names_out()
# Out:
# array(['days_since_opened', 'days_since_confirmed', 'primary_term',
#        'final_term', 'days_till_primary_close', 'days_till_final_close',
#        'loans_outstanding_balance', 'loans_max_overdue_amount',
#        'loans_within_5_days', 'loans_within_5_to_30_days',
#        'loans_within_30_to_60_days', 'loans_within_60_to_90_days',
#        'loans_over_90_days', 'is_zero_loans_within_5_days',
#        'is_zero_loans_within_5_to_30_days',
#        'is_zero_loans_within_30_to_60_days',
#        'is_zero_loans_within_60_to_90_days', 'is_zero_loans_over_90_days',
#        'utilization', 'over_limit_count', 'max_over_limit_count',
#        'is_zero_utilization', 'is_zero_over_limit_count',
#        'is_zero_max_over_limit_count', 'encoded_payment_8',
#        'encoded_payment_9', 'encoded_payment_10', 'encoded_payment_11',
#        'encoded_payment_12', 'encoded_payment_13', 'encoded_payment_14',
#        'encoded_payment_15', 'encoded_payment_16', 'encoded_payment_17',
# ...

# %%
feature_set_1 = pd.DataFrame(x_new, columns=selector.get_feature_names_out())

# %%
feature_set_1
# Out:
#          days_since_opened  days_since_confirmed  primary_term  final_term  \
# 0                     10.0                   8.0          12.0        10.0
# 1                     15.0                   6.0           7.0         6.0
# 2                     15.0                  17.0           8.0         5.0
# 3                      7.0                   2.0          11.0        13.0
# 4                     14.0                   9.0           8.0        11.0
# ...                    ...                   ...           ...         ...
# 1790493               19.0                  10.0           3.0         8.0
# 1790494               12.0                  16.0          11.0         8.0
# 1790495                3.0                   9.0           4.0         8.0
# 1790496                4.0                  17.0           4.0         8.0
# 1790497                1.0                  10.0          11.0         8.0
#
#          days_till_primary_close  days_till_final_close  \
# ...

# %%
feature_set_1.to_csv('Features_Credit_Risk_Analysis.csv')

# %% [markdown]
# # Data Splitting

# %%
# Splitting dataset with Train Size (97.5% of total) & Test Size (2.5% of total)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(feature_set_1, y_final_close, test_size = 0.30,random_state=42)

# %%
X_train.shape
# Out:
# (1253348, 45)

# %% [markdown]
# # DATA TRANSFORMATION

# %%
# Z-score based normalization
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.decomposition import PCA  

# captures 55% variance i.e. if there will be high variance there will be overfitting, so there has to be trade off b/w bias and variance 
pca = PCA(0.55) 

X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.fit_transform(X_test_scaled)

# %%
X_train.shape
# Out:
# (1253348, 45)

# %%
X_train_pca.shape
# Out:
# (1253348, 7)

# %% [markdown]
# # MODELLING

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier 
import tensorflow as tf 
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, LeakyReLU
from sklearn.metrics import classification_report, accuracy_score

# %%
models = [LogisticRegression(max_iter=2000), DecisionTreeClassifier(), RandomForestClassifier()]

# %%
# Without PCA with 45 features
for model in models:
    model.fit(X_train_scaled,y_train)
    print(f'Accuracy of {model} on train data is {100*model.score(X_train_scaled,y_train)}')
    print(f'Accuracy of {model} on test data is {100*model.score(X_test_scaled,y_test)}')
    y_pred = model.predict(X_test_scaled)
    print(classification_report(y_test,y_pred))
    print('*****************************************************************')
# Out:
# Accuracy of LogisticRegression(max_iter=2000) on train data is 86.8035054908932
# Accuracy of LogisticRegression(max_iter=2000) on test data is 86.7003630270874
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87    268410
#            1       0.86      0.88      0.87    268740
#
#     accuracy                           0.87    537150
#    macro avg       0.87      0.87      0.87    537150
# weighted avg       0.87      0.87      0.87    537150
#
# *****************************************************************
# Accuracy of DecisionTreeClassifier() on train data is 99.65141365367
# Accuracy of DecisionTreeClassifier() on test data is 99.41245462161407
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    268410
#            1       0.99      1.00      0.99    268740
#
#     accuracy                           0.99    537150
# ...

# %%
# After PCA with 26 components
for model in models:
    model.fit(X_train_pca,y_train)
    print(f'Accuracy of {model} on train data is {100*model.score(X_train_pca,y_train)}')
    print(f'Accuracy of {model} on test data is {100*model.score(X_test_pca,y_test)}')
    y_pred = model.predict(X_test_pca)
    print(classification_report(y_test,y_pred))
    print('*****************************************************************')
# Out:
# Accuracy of LogisticRegression(max_iter=2000) on train data is 85.45479786938664
# Accuracy of LogisticRegression(max_iter=2000) on test data is 85.4018430605976
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85    268410
#            1       0.85      0.86      0.85    268740
#
#     accuracy                           0.85    537150
#    macro avg       0.85      0.85      0.85    537150
# weighted avg       0.85      0.85      0.85    537150
#
# *****************************************************************
# Accuracy of DecisionTreeClassifier() on train data is 99.65141365367
# Accuracy of DecisionTreeClassifier() on test data is 89.67606813739178
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90    268410
#            1       0.92      0.87      0.89    268740
#
#     accuracy                           0.90    537150
# ...

# %%
model = Sequential()

model.add(Dense(50,activation='ReLU',input_dim=45))
model.add(Dense(45, activation='ReLU'))
model.add(Dense(40, activation='ReLU'))
model.add(Dense(35, activation='ReLU'))
model.add(Dense(30, activation='ReLU'))
model.add(Dense(25, activation='ReLU'))
model.add(Dense(20, activation='ReLU'))
model.add(Dense(15, activation='ReLU'))
model.add(Dense(10, activation='ReLU'))
model.add(Dense(5, activation='ReLU'))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_349 (Dense)           (None, 50)                2300
#
#  dense_350 (Dense)           (None, 45)                2295
#
#  dense_351 (Dense)           (None, 40)                1840
#
#  dense_352 (Dense)           (None, 35)                1435
#
#  dense_353 (Dense)           (None, 30)                1080
#
#  dense_354 (Dense)           (None, 25)                775
#
#  dense_355 (Dense)           (None, 20)                520
#
#  dense_356 (Dense)           (None, 15)                315
#
#  dense_357 (Dense)           (None, 10)                160
#
#  dense_358 (Dense)           (None, 5)                 55
#
#  dense_359 (Dense)           (None, 1)                 6
#
# ...
# Total params: 10781 (42.11 KB)
# Trainable params: 10781 (42.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
# Early Stopping is appliead to prevent unnecessary epochs,epoch after which validation loss begins to increase there early stopping will be called
callbacks = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=0,
    verbose=1,
    mode='min',
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0
)

# %%
history = model.fit(X_train_scaled,y_train,validation_split=0.40,epochs=30,callbacks=callbacks)
# Out:
# Epoch 1/30
# 23501/23501 [==============================] - 44s 2ms/step - loss: 0.0285 - accuracy: 0.9903 - val_loss: 0.0167 - val_accuracy: 0.9940
# Epoch 2/30
# 23501/23501 [==============================] - 42s 2ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0157 - val_accuracy: 0.9940
# Epoch 3/30
# 23501/23501 [==============================] - 42s 2ms/step - loss: 0.0162 - accuracy: 0.9941 - val_loss: 0.0153 - val_accuracy: 0.9942
# Epoch 4/30
# 23501/23501 [==============================] - 42s 2ms/step - loss: 0.0158 - accuracy: 0.9941 - val_loss: 0.0161 - val_accuracy: 0.9942
# Epoch 4: early stopping

# %%
plt.plot(history.history['loss'],color='orange')
plt.plot(history.history['val_loss'],color='blue') 
plt.xlabel('Number Of Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(history.history['accuracy'],color='orange')
plt.plot(history.history['val_accuracy'],color='blue') 
plt.xlabel('Number Of Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Out of all models implemented, ANN gave best result i.e. there is no overfitting

# %% [markdown]
# # MODEL EVALUATION

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 16786/16786 [==============================] - 12s 735us/step

# %%
y_pred_1 = np.where(y_pred>0.5,1,0)

# %%
y_pred_1 = pd.DataFrame(y_pred_1,columns=['Target'])
y_pred_1
# Out:
#         Target
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# ...        ...
# 537145       1
# 537146       1
# 537147       1
# 537148       1
# 537149       0
#
# [537150 rows x 1 columns]

# %%
accuracy_score(y_test,y_pred_1)
# Out:
# 0.9941729498277948

# %%
print(classification_report(y_test,y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    268410
#            1       0.99      1.00      0.99    268740
#
#     accuracy                           0.99    537150
#    macro avg       0.99      0.99      0.99    537150
# weighted avg       0.99      0.99      0.99    537150

# %%
model.save('Credit_Risk_Assessment_Model.h5')
# Out:
# e:\Program Files\python\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
